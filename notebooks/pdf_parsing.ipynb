# %%
import pymupdf as fitz

pdf_patyh = "/Users/arjunv/Desktop/projects/career-copilot/data/Arjun_V-DS-ML-V1.pdf"

# %%
document = fitz.open(pdf_patyh)
for page in document:
    text = page.get_text()
    print(text)
# Out:
# Arjun V
# Data Scientist | Applied AI Engineer | ML Systems Builder
# arjunvijayan.452​@gmail.com
#
# +918606235370
#
# Kochi, Kerala
#
# Linkedin
#
# GitHub
#
# PROFESSIONAL SUMMARY
# Data Scientist with ~4 years of experience building production-grade ML and AI systems for real-world business applications.
# Strong focus on problem-solving, system design, and scalable implementations, with experience across predictive modeling,
# document intelligence, and workflow automation.
# PROFESSIONAL EXPERIENCE
# Senior Associate Data Science, Publicis Sapient
# 07/2025 – Present  | Bangalore
# •Built systems to extract and structure pricing and commercial terms from contracts and invoices using document intelligence
# and rule-based + ML pipelines
# •Developed a pricing validation engine to verify contract logic against operational data, reducing manual effort by 30–40%
# •Designed normalization pipelines to handle heterogeneous document formats at scale
# •Implemented confidence scoring and validation workflows to support human-in-the-loop review
# •Built semantic retrieval layers for efficient querying over enterprise documents
# •Worked with distributed teams on system design and deliver
# Data Scientist L1, Prezent Al Pvt Ltd
# 10/2024 – 07/2025
# AI-Powered Document-to-Presentation System
# •Developed an AI-powered presentation generation system that converts Excel/​CSV inputs and user prompts into structured
# slide decks using storyline planning, template matching, and layout optimization, reducing manual effort by ~75%
# •Architected a multi-stage agentic AI pipeline performing - intent classification from user prompts, storyline and slide-level
# planning, template mapping and layout adaptation and automated generation of charts, visuals, and contextual narratives.
# •Built a robust Excel parsing engine handling complex formats (nested headers, irregular layouts) with ~80% structured
# extraction accuracy
# •Improved system throughput by 40%+ using asynchronous LLM orchestration and parallel processing
# •Enabled natural language querying over structured data via semantic indexing.
# MTS - Data Scientist, ZOHO Corporation Pvt Ltd
# 07/2022 – 10/2024
# Predictive Retention & Behavioral Modeling
# •Built and deployed a CRM-integrated churn prediction system on 50K+ users with 76% accuracy and 30-day risk forecasting
# •Engineered longitudinal behavioral features (purchase velocity, engagement intervals) to improve predictive robustness
# •Automated EDA and feature engineering workflows, reducing model development time by 40%
# •Implemented SHAP-based explainability to surface actionable churn drivers
# •Developed survival analysis models to predict time-to-next purchase for demand and inventory planning
# •Built resume parsing system (DL → LLM migration using Mistral) for semi-structured document extraction.
# EDUCATION
# Bachelor of Technology, Electrical and Electronics Engineering,,
# College of Engineering Chengannur
# 07/2018 – 07/2022  | Alappuzha, India
# Activities and societies: National Service Scheme Volunteer, Placement cell Coordinator, Served as student representative
# TECHNICAL SKILLS
# Machine Learning
# Supervised Learning (XGBoost, LightGBM, CatBoost, Scikit-
# learn) | Unsupervised Learning | Reinforcement Learning
# NLP and LLMs
# Traditional NLP: NLTK, SpaCy, Text Classification | LLMs:
# Claude, GPT, Gemini, RAG architectures | Tooling: LangChain,
# LlamaIndex, Al Agents Vector databases: FAISS, Qdrant,
# ChromaDB
# Tools
# Languages: Python, SQL, C | IDEs: VSCode, PyCharm, Jupyter,
# Codex | Data Processing: Pandas, NumPy, SciPy
# Deep Learning
# DNN, CNN, RNN/​LSTM, Transformers | TensorFlow, PyTorch,
# Keras | BERT, Hugging Face, Mistral
# Data Visualisation
# Libraries: Matplotlib, Seaborn, Plotly | App Builders:
# Streamlit, Gradio
# MLOps
# Version Control: Git, GitHub | CI/​CD: Jenkins, GitHub Actions |
# Cloud Platforms: AWS (EC2, S3, CloudWatch), Azure,
# Container Jobs, Monitor, App Insights, Blob Storage |
# Deployment: Docker, FastAPI

# %%
tables = []
for page in document:
    blocks = page.get_text("blocks")
    for block in blocks:
        if block[6] == 5:  # Check if the block is a table
            tables.append(block)    
print(f"Found {len(tables)} tables in the PDF.")
# Out:
# Found 0 tables in the PDF.

# %%
images = []
for page in document:
    blocks = page.get_text("blocks")
    for block in blocks:
        if block[6] == 1:  # Check if the block is an image
            images.append(block)
print(f"Found {len(images)} images in the PDF.")
# Out:
# Found 0 images in the PDF.

# %%
urls = []
for page in document:
    for link in page.get_links():
        uri = link.get("uri")
        if uri:
            urls.append(uri)

print(f"Found {len(urls)} URLs in the PDF.")
print(urls)
# Out:
# Found 4 URLs in the PDF.
# ['mailto:arjunvijayan.452@gmail.com', 'tel:+918606235370', 'https://www.linkedin.com/in/arjun-v-5110b11a9/?profileId=ACoAADCaFJ0Bo_mr-eu5xeyTPQK4dMntxtUqmNY', 'https://github.com/ArjunVijayan']

# %%
img_path = "/Users/arjunv/Desktop/projects/career-copilot/data/scanned-resume-sample.jpg"

# %%
import pytesseract
from PIL import Image
text = pytesseract.image_to_string(Image.open(img_path))
print(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Desktop/projects/career-copilot/.venv/lib/python3.14/site-packages/pytesseract/pytesseract.py:275, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     274 try:
# --> 275     proc = subprocess.Popen(cmd_args, **subprocess_args())
#     276 except OSError as e:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.4/Frameworks/Python.framework/Versions/3.14/lib/python3.14/subprocess.py:1039, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1036             self.stderr = io.TextIOWrapper(self.stderr,
#    1037                     encoding=encoding, errors=errors)
# -> 1039     self._execute_child(args, executable, preexec_fn, close_fds,
#    1040                         pass_fds, cwd, env,
#    1041                         startupinfo, creationflags, shell,
#    1042                         p2cread, p2cwrite,
#    1043                         c2pread, c2pwrite,
#    1044                         errread, errwrite,
#    1045                         restore_signals,
#    1046                         gid, gids, uid, umask,
#    1047                         start_new_session, process_group)
#    1048 except:
#    1049     # Cleanup if the child failed starting.
#
# File /opt/homebrew/Cellar/python@3.14/3.14.4/Frameworks/Python.framework/Versions/3.14/lib/python3.14/subprocess.py:1990, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1989 if err_filename is not None:
# -> 1990     raise child_exception_type(errno_num, err_msg, err_filename)
#    1991 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tesseract'
#
# During handling of the above exception, another exception occurred:
#
# TesseractNotFoundError                    Traceback (most recent call last)
# Cell In[9], line 3
#       1 import pytesseract
#       2 from PIL import Image
# ----> 3 text = pytesseract.image_to_string(Image.open(img_path))
#       4 print(text)
#
# File ~/Desktop/projects/career-copilot/.venv/lib/python3.14/site-packages/pytesseract/pytesseract.py:486, in image_to_string(image, lang, config, nice, output_type, timeout)
#     481 """
#     482 Returns the result of a Tesseract OCR run on the provided image to string
#     483 """
#     484 args = [image, 'txt', lang, config, nice, timeout]
# --> 486 return {
#     487     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     488     Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     489     Output.STRING: lambda: run_and_get_output(*args),
#     490 }[output_type]()
#
# File ~/Desktop/projects/career-copilot/.venv/lib/python3.14/site-packages/pytesseract/pytesseract.py:489, in image_to_string.<locals>.<lambda>()
#     481 """
#     482 Returns the result of a Tesseract OCR run on the provided image to string
#     483 """
#     484 args = [image, 'txt', lang, config, nice, timeout]
#     486 return {
#     487     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     488     Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 489     Output.STRING: lambda: run_and_get_output(*args),
#     490 }[output_type]()
#
# File ~/Desktop/projects/career-copilot/.venv/lib/python3.14/site-packages/pytesseract/pytesseract.py:352, in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     341 with save(image) as (temp_name, input_filename):
#     342     kwargs = {
#     343         'input_filename': input_filename,
#     344         'output_filename_base': temp_name,
#    (...)    349         'timeout': timeout,
#     350     }
# --> 352     run_tesseract(**kwargs)
#     353     return _read_output(
#     354         f"{kwargs['output_filename_base']}{extsep}{extension}",
#     355         return_bytes,
#     356     )
#
# File ~/Desktop/projects/career-copilot/.venv/lib/python3.14/site-packages/pytesseract/pytesseract.py:280, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     278         raise
#     279     else:
# --> 280         raise TesseractNotFoundError()
#     282 with timeout_manager(proc, timeout) as error_string:
#     283     if proc.returncode:
#
# TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information.
